# %% [markdown]
# # Stages
#
# 1.   Load data
# 2.   Check data
# 3.   Prepare data for spacy
# 4.   Implement the model
# 5.   Evaluate the results

# %%
import pandas as pd
import spacy
import re
import requests, json 
import plac
import random
from spacy.util import minibatch, compounding

# %% [markdown]
# Let's download a sample dataset with 100 annotated recipes

# %%
sheet_id = "1r6sqFGnPqPYsXL0BYVH60DAsXfHuT2w0"
sheet_name = "Sheet1"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"

# %%
data = pd.read_csv(url)

# %%
data.head()
# Out:
#    Unnamed: 0  ...             Startup
# 0           0  ...              accedo
# 1           1  ...               uniti
# 2           2  ...        syqe medical
# 3           3  ...  alphonse's talents
# 4           4  ...               libon
#
# [5 rows x 3 columns]

# %%
new_data = []
for idx, startup in data.iterrows():
# getting the index of company names in the heading
    new_data.append([m.span() for m in re.finditer(startup['Startup'], startup['Headline'])])
data['my_index'] = new_data

spacy_data = []
for idx, row in data.iterrows():
# setting up data according to spacy requirements
   spacy_data.append([row.Headline, {"entities": [(row['my_index'][0][0],row['my_index'][0][1], "ORG")]}])

# %%
idx = 0
spacy_data[idx]
# Out:
# ['accedo raises us$17 million in funding', {'entities': [(0, 6, 'ORG')]}]

# %%
for entity in spacy_data[idx][1]['entities']:
  print(entity[2],spacy_data[idx][0][entity[0]:entity[1]])
# Out:
# ORG accedo

# %% [markdown]
# Building a train/test split after a random shuffle

# %%
random.shuffle(spacy_data)
train_data_size = round(len(spacy_data) * 0.8)
print(len(spacy_data), train_data_size)
# Out:
# 2797 2238

# %%
train_data = spacy_data[:train_data_size]
test_data = spacy_data[train_data_size:]

print(len(train_data))
print(len(test_data))
# Out:
# 2238
# 559

# %% [markdown]
# Loading the default spacy model and setting up the ner ML pipeline.
#
# The training process for spacy is deailed here: https://spacy.io/usage/training#ner

# %%
nlp = spacy.blank("en")
if "ner" not in nlp.pipe_names:
    print('no ner')
    ner = nlp.create_pipe("ner")
    nlp.add_pipe(ner, last=True)
else:
    print('add ner')
    ner = nlp.get_pipe("ner")
# Out:
# no ner

# %% [markdown]
# Counting how many annotating we have for every type.

# %%
labels = {}
for _, annotations in train_data:
        for ent in annotations.get("entities"):
            ner.add_label(ent[2])
            if(ent[2] not in labels):
                labels[ent[2]] = 1
            else:
              labels[ent[2]] +=1
print(labels)
# Out:
# {'ORG': 2238}

# %%
n_iter=200

# %%
other_pipes = [pipe for pipe in nlp.pipe_names if pipe != "ner"]
with nlp.disable_pipes(*other_pipes):  # only train NER
    # reset and initialize the weights randomly – but only if we're
    # training a new model
    nlp.vocab.vectors.name = 'startup_pretrained_entities'
    nlp.begin_training()
    for itn in range(n_iter):
        random.shuffle(train_data)
        losses = {}
        # batch up the examples using spaCy's minibatch
        batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
        for batch in batches:
            texts, annotations = zip(*batch)
#            print([(text,annotation) for text,annotation in zip(texts,annotations)])
            nlp.update(
                texts,  # batch of texts
                annotations,  # batch of annotations
                drop=0.5,  # dropout - make it harder to memorise data
                losses=losses,
            )
        print("Iteration {} Losses".format(itn), losses)
# Out:
# Iteration 0 Losses {'ner': 2296.5528093623475}
# Iteration 1 Losses {'ner': 1270.6767905932068}
# Iteration 2 Losses {'ner': 1028.8381617840341}
# Iteration 3 Losses {'ner': 821.0313050316771}
# Iteration 4 Losses {'ner': 660.8623107860788}
# Iteration 5 Losses {'ner': 559.2208392989152}
# Iteration 6 Losses {'ner': 548.4058385584626}
# Iteration 7 Losses {'ner': 482.80468972725663}
# Iteration 8 Losses {'ner': 453.8788751776386}
# Iteration 9 Losses {'ner': 385.1315311223855}
# Iteration 10 Losses {'ner': 372.05361884063973}
# Iteration 11 Losses {'ner': 370.1791273927845}
# Iteration 12 Losses {'ner': 310.7235501786462}
# Iteration 13 Losses {'ner': 261.8098228361881}
# Iteration 14 Losses {'ner': 280.2500282545643}
# Iteration 15 Losses {'ner': 262.72343357811286}
# Iteration 16 Losses {'ner': 223.83822574982085}
# Iteration 17 Losses {'ner': 204.9107073922918}
# Iteration 18 Losses {'ner': 206.47318216952155}
# Iteration 19 Losses {'ner': 156.33964898439538}
# Iteration 20 Losses {'ner': 184.68527874989684}
# Iteration 21 Losses {'ner': 219.66132813551476}
# Iteration 22 Losses {'ner': 179.94121721366298}
# Iteration 23 Losses {'ner': 145.20987918179085}
# Iteration 24 Losses {'ner': 167.00029351161663}
# Iteration 25 Losses {'ner': 163.24950186605093}
# Iteration 26 Losses {'ner': 145.11651071111672}
# Iteration 27 Losses {'ner': 155.91367313263456}
# Iteration 28 Losses {'ner': 120.38716453742633}
# Iteration 29 Losses {'ner': 126.71099320147347}
# Iteration 30 Losses {'ner': 129.81512764310526}
# Iteration 31 Losses {'ner': 110.85301628277716}
# Iteration 32 Losses {'ner': 106.06758647790238}
# Iteration 33 Losses {'ner': 135.2062554095348}
# Iteration 34 Losses {'ner': 128.76441713984718}
# Iteration 35 Losses {'ner': 134.10274858208686}
# Iteration 36 Losses {'ner': 77.25762673228965}
# Iteration 37 Losses {'ner': 131.62766569506547}
# Iteration 38 Losses {'ner': 128.74470836471554}
# Iteration 39 Losses {'ner': 98.30672637659102}
# Iteration 40 Losses {'ner': 82.29210278678549}
# Iteration 41 Losses {'ner': 99.77915598410274}
# Iteration 42 Losses {'ner': 59.26539705542928}
# Iteration 43 Losses {'ner': 122.9392798211879}
# Iteration 44 Losses {'ner': 112.77439435900844}
# Iteration 45 Losses {'ner': 79.76088559709508}
# Iteration 46 Losses {'ner': 84.36192179003862}
# Iteration 47 Losses {'ner': 99.54812376818926}
# Iteration 48 Losses {'ner': 137.8283187225528}
# Iteration 49 Losses {'ner': 108.08774981524485}
# Iteration 50 Losses {'ner': 79.51620928766773}
# Iteration 51 Losses {'ner': 89.38923909666195}
# Iteration 52 Losses {'ner': 60.214011090339}
# Iteration 53 Losses {'ner': 63.99357921045163}
# Iteration 54 Losses {'ner': 53.973221310951224}
# Iteration 55 Losses {'ner': 92.72432408956527}
# Iteration 56 Losses {'ner': 71.19072332090826}
# Iteration 57 Losses {'ner': 65.3089518923894}
# Iteration 58 Losses {'ner': 74.87865561573376}
# Iteration 59 Losses {'ner': 92.618667241589}
# Iteration 60 Losses {'ner': 78.02328782394608}
# Iteration 61 Losses {'ner': 84.64942308717436}
# Iteration 62 Losses {'ner': 81.78461086440446}
# Iteration 63 Losses {'ner': 93.65621075086113}
# Iteration 64 Losses {'ner': 87.55191283276254}
# Iteration 65 Losses {'ner': 54.746958583299374}
# Iteration 66 Losses {'ner': 55.442397328315266}
# Iteration 67 Losses {'ner': 50.40123786143093}
# Iteration 68 Losses {'ner': 56.70021152568737}
# Iteration 69 Losses {'ner': 53.73457989790706}
# Iteration 70 Losses {'ner': 93.66024068288002}
# Iteration 71 Losses {'ner': 65.03057703793807}
# Iteration 72 Losses {'ner': 73.43752119306913}
# Iteration 73 Losses {'ner': 34.96190314949395}
# Iteration 74 Losses {'ner': 91.45220140885698}
# Iteration 75 Losses {'ner': 64.17468689640405}
# Iteration 76 Losses {'ner': 32.964298106431926}
# Iteration 77 Losses {'ner': 72.27703152792131}
# Iteration 78 Losses {'ner': 73.31572927246442}
# Iteration 79 Losses {'ner': 71.83112601687081}
# Iteration 80 Losses {'ner': 58.03286543086292}
# Iteration 81 Losses {'ner': 49.803484900232355}
# Iteration 82 Losses {'ner': 45.6955528813392}
# Iteration 83 Losses {'ner': 57.282924275586055}
# Iteration 84 Losses {'ner': 51.155444166688746}
# Iteration 85 Losses {'ner': 60.32124770823208}
# Iteration 86 Losses {'ner': 60.13291217636726}
# Iteration 87 Losses {'ner': 72.2402388139672}
# Iteration 88 Losses {'ner': 78.90187010302246}
# Iteration 89 Losses {'ner': 89.84194948567074}
# Iteration 90 Losses {'ner': 66.25063503836238}
# Iteration 91 Losses {'ner': 68.51282095124257}
# Iteration 92 Losses {'ner': 48.19170575790415}
# Iteration 93 Losses {'ner': 46.741659230236266}
# Iteration 94 Losses {'ner': 82.13323173246286}
# Iteration 95 Losses {'ner': 65.58062987903801}
# Iteration 96 Losses {'ner': 86.15713895339307}
# Iteration 97 Losses {'ner': 65.53773953017073}
# Iteration 98 Losses {'ner': 69.83714316513675}
# Iteration 99 Losses {'ner': 53.191329573371036}
# Iteration 100 Losses {'ner': 81.58185692639177}
# Iteration 101 Losses {'ner': 51.195028052499055}
# Iteration 102 Losses {'ner': 44.01194087705069}
# Iteration 103 Losses {'ner': 67.12300057172263}
# Iteration 104 Losses {'ner': 41.79641969752747}
# Iteration 105 Losses {'ner': 58.582917117998726}
# Iteration 106 Losses {'ner': 68.411855063769}
# Iteration 107 Losses {'ner': 58.84228118348048}
# Iteration 108 Losses {'ner': 51.633168268382725}
# Iteration 109 Losses {'ner': 74.43317947752708}
# Iteration 110 Losses {'ner': 53.264099630963145}
# Iteration 111 Losses {'ner': 62.191294106946366}
# Iteration 112 Losses {'ner': 50.651551823959274}
# Iteration 113 Losses {'ner': 52.12658404257889}
# Iteration 114 Losses {'ner': 47.93096897482569}
# Iteration 115 Losses {'ner': 46.95991441491986}
# Iteration 116 Losses {'ner': 44.233853401104064}
# Iteration 117 Losses {'ner': 63.843332300049106}
# Iteration 118 Losses {'ner': 64.77329725081643}
# Iteration 119 Losses {'ner': 42.6477777847001}
# Iteration 120 Losses {'ner': 38.73790870032761}
# Iteration 121 Losses {'ner': 31.985085929860315}
# Iteration 122 Losses {'ner': 48.52706362318486}
# Iteration 123 Losses {'ner': 54.71788950454594}
# Iteration 124 Losses {'ner': 47.506535541832434}
# Iteration 125 Losses {'ner': 48.13548482636995}
# Iteration 126 Losses {'ner': 47.2671753307297}
# Iteration 127 Losses {'ner': 69.87059402378637}
# Iteration 128 Losses {'ner': 43.29032720628042}
# Iteration 129 Losses {'ner': 50.8247403283086}
# Iteration 130 Losses {'ner': 50.71021835678491}
# Iteration 131 Losses {'ner': 63.52120039968172}
# Iteration 132 Losses {'ner': 57.46989202305478}
# Iteration 133 Losses {'ner': 45.92017658653538}
# Iteration 134 Losses {'ner': 39.41371377003705}
# Iteration 135 Losses {'ner': 31.824241239428147}
# Iteration 136 Losses {'ner': 52.58443031876476}
# Iteration 137 Losses {'ner': 46.68284542626367}
# Iteration 138 Losses {'ner': 43.29948818153535}
# Iteration 139 Losses {'ner': 44.9478902260914}
# Iteration 140 Losses {'ner': 35.24804430941915}
# Iteration 141 Losses {'ner': 57.30356448155607}
# Iteration 142 Losses {'ner': 57.5031348870008}
# Iteration 143 Losses {'ner': 54.261248041853676}
# Iteration 144 Losses {'ner': 44.37301381819403}
# Iteration 145 Losses {'ner': 51.41756831685357}
# Iteration 146 Losses {'ner': 44.23004571846735}
# Iteration 147 Losses {'ner': 37.51294140928992}
# Iteration 148 Losses {'ner': 42.425720333341644}
# Iteration 149 Losses {'ner': 38.27238145736322}
# Iteration 150 Losses {'ner': 62.65676013439822}
# Iteration 151 Losses {'ner': 53.23453415268381}
# Iteration 152 Losses {'ner': 49.509290420550585}
# Iteration 153 Losses {'ner': 41.01566713642444}
# Iteration 154 Losses {'ner': 38.71464539823937}
# Iteration 155 Losses {'ner': 43.44872035909694}
# Iteration 156 Losses {'ner': 51.118615996601996}
# Iteration 157 Losses {'ner': 57.56923358885726}
# Iteration 158 Losses {'ner': 43.645402649552175}
# Iteration 159 Losses {'ner': 67.12982751099172}
# Iteration 160 Losses {'ner': 47.86998651846996}
# Iteration 161 Losses {'ner': 47.131126035386494}
# Iteration 162 Losses {'ner': 24.461667904830435}
# Iteration 163 Losses {'ner': 47.31561439709969}
# Iteration 164 Losses {'ner': 52.9370940905868}
# Iteration 165 Losses {'ner': 88.69125862066572}
# Iteration 166 Losses {'ner': 42.59648136321782}
# Iteration 167 Losses {'ner': 36.95963211375446}
# Iteration 168 Losses {'ner': 41.62316879020126}
# Iteration 169 Losses {'ner': 40.033602239147996}
# Iteration 170 Losses {'ner': 38.955710626529495}
# Iteration 171 Losses {'ner': 43.89011665577925}
# Iteration 172 Losses {'ner': 46.78265796152518}
# Iteration 173 Losses {'ner': 56.15864263489105}
# Iteration 174 Losses {'ner': 54.655068300704436}
# Iteration 175 Losses {'ner': 50.61605730333387}
# Iteration 176 Losses {'ner': 64.2349344250826}
# Iteration 177 Losses {'ner': 61.506035269567874}
# Iteration 178 Losses {'ner': 57.06819840421258}
# Iteration 179 Losses {'ner': 41.937828365227816}
# Iteration 180 Losses {'ner': 31.107315285759633}
# Iteration 181 Losses {'ner': 55.47837195347842}
# Iteration 182 Losses {'ner': 51.31500758392784}
# Iteration 183 Losses {'ner': 13.731366432399874}
# Iteration 184 Losses {'ner': 25.337678179462433}
# Iteration 185 Losses {'ner': 36.0142268988808}
# Iteration 186 Losses {'ner': 55.53632051338003}
# Iteration 187 Losses {'ner': 53.69190523997721}
# Iteration 188 Losses {'ner': 43.58107281742399}
# Iteration 189 Losses {'ner': 52.511393565135116}
# Iteration 190 Losses {'ner': 56.41431638588155}
# Iteration 191 Losses {'ner': 49.137045919889324}
# Iteration 192 Losses {'ner': 46.268437372513944}
# Iteration 193 Losses {'ner': 46.57950329556348}
# Iteration 194 Losses {'ner': 47.953966822026764}
# Iteration 195 Losses {'ner': 66.57710013707688}
# Iteration 196 Losses {'ner': 39.906003572139085}
# Iteration 197 Losses {'ner': 54.16771815403012}
# Iteration 198 Losses {'ner': 50.17515867601268}
# Iteration 199 Losses {'ner': 24.78883856429139}

# %% [markdown]
# We can apply the fitted model to new text

# %%
for text, _ in test_data:
    doc = nlp(text)
    print(text)
    print("Entities", [(ent.text, ent.label_) for ent in doc.ents])
    print("Tokens", [(t.text, t.ent_type_, t.ent_iob_) for t in doc])
    print()
# Out:
# implicity raises €4 million in funding
# Entities [('implicity', 'ORG')]
# Tokens [('implicity', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('4', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# beringea leads £2.4 million investment in deepcrawl
# Entities [('deepcrawl', 'ORG')]
# Tokens [('beringea', '', 'O'), ('leads', '', 'O'), ('£', '', 'O'), ('2.4', '', 'O'), ('million', '', 'O'), ('investment', '', 'O'), ('in', '', 'O'), ('deepcrawl', 'ORG', 'B')]
#
# versameb raises €5.5 million in seed c funding round
# Entities [('versameb', 'ORG')]
# Tokens [('versameb', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('5.5', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('seed', '', 'O'), ('c', '', 'O'), ('funding', '', 'O'), ('round', '', 'O')]
#
# israeli b2b marketing platform folloze raises $11 million
# Entities [('folloze', 'ORG')]
# Tokens [('israeli', '', 'O'), ('b2b', '', 'O'), ('marketing', '', 'O'), ('platform', '', 'O'), ('folloze', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('11', '', 'O'), ('million', '', 'O')]
#
# edtech startup blackbullion closes £400,000 post-seed funding round
# Entities [('blackbullion', 'ORG')]
# Tokens [('edtech', '', 'O'), ('startup', '', 'O'), ('blackbullion', 'ORG', 'B'), ('closes', '', 'O'), ('£', '', 'O'), ('400,000', '', 'O'), ('post', '', 'O'), ('-', '', 'O'), ('seed', '', 'O'), ('funding', '', 'O'), ('round', '', 'O')]
#
# €12.5 million for berlin solar startup home power solutions
# Entities [('home power solutions', 'ORG')]
# Tokens [('€', '', 'O'), ('12.5', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('berlin', '', 'O'), ('solar', '', 'O'), ('startup', '', 'O'), ('home', 'ORG', 'B'), ('power', 'ORG', 'I'), ('solutions', 'ORG', 'I')]
#
# roompricegenie raises €860,000  round led by wingman ventures
# Entities [('roompricegenie', 'ORG')]
# Tokens [('roompricegenie', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('860,000', '', 'O'), (' ', '', 'O'), ('round', '', 'O'), ('led', '', 'O'), ('by', '', 'O'), ('wingman', '', 'O'), ('ventures', '', 'O')]
#
# the zukunftsfonds heilbronn and the high-tech gründerfonds (htgf) invest in the bochum startup zolitron
# Entities [('zolitron', 'ORG')]
# Tokens [('the', '', 'O'), ('zukunftsfonds', '', 'O'), ('heilbronn', '', 'O'), ('and', '', 'O'), ('the', '', 'O'), ('high', '', 'O'), ('-', '', 'O'), ('tech', '', 'O'), ('gründerfonds', '', 'O'), ('(', '', 'O'), ('htgf', '', 'O'), (')', '', 'O'), ('invest', '', 'O'), ('in', '', 'O'), ('the', '', 'O'), ('bochum', '', 'O'), ('startup', '', 'O'), ('zolitron', 'ORG', 'B')]
#
# abn amro invests in israeli big data co thetaray
# Entities [('thetaray', 'ORG')]
# Tokens [('abn', '', 'O'), ('amro', '', 'O'), ('invests', '', 'O'), ('in', '', 'O'), ('israeli', '', 'O'), ('big', '', 'O'), ('data', '', 'O'), ('co', '', 'O'), ('thetaray', 'ORG', 'B')]
#
# data management company veeam raises a whopping $500 million from insight vp
# Entities [('veeam', 'ORG')]
# Tokens [('data', '', 'O'), ('management', '', 'O'), ('company', '', 'O'), ('veeam', 'ORG', 'B'), ('raises', '', 'O'), ('a', '', 'O'), ('whopping', '', 'O'), ('$', '', 'O'), ('500', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('insight', '', 'O'), ('vp', '', 'O')]
#
# mcmakler raises $20 million  in secondary funding
# Entities [('mcmakler', 'ORG')]
# Tokens [('mcmakler', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('20', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('secondary', '', 'O'), ('funding', '', 'O')]
#
# a high six-figure sum invested in hamburg startup comydo
# Entities [('comydo', 'ORG')]
# Tokens [('a', '', 'O'), ('high', '', 'O'), ('six', '', 'O'), ('-', '', 'O'), ('figure', '', 'O'), ('sum', '', 'O'), ('invested', '', 'O'), ('in', '', 'O'), ('hamburg', '', 'O'), ('startup', '', 'O'), ('comydo', 'ORG', 'B')]
#
# israeli data protection startup satori cyber adds $5.5 million  in funding
# Entities [('satori cyber', 'ORG')]
# Tokens [('israeli', '', 'O'), ('data', '', 'O'), ('protection', '', 'O'), ('startup', '', 'O'), ('satori', 'ORG', 'B'), ('cyber', 'ORG', 'I'), ('adds', '', 'O'), ('$', '', 'O'), ('5.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# ecapital, born2grow, avala capital and seed x liechtenstein are investing a mid-single-digit million amount in troy
# Entities [('troy', 'ORG')]
# Tokens [('ecapital', '', 'O'), (',', '', 'O'), ('born2grow', '', 'O'), (',', '', 'O'), ('avala', '', 'O'), ('capital', '', 'O'), ('and', '', 'O'), ('seed', '', 'O'), ('x', '', 'O'), ('liechtenstein', '', 'O'), ('are', '', 'O'), ('investing', '', 'O'), ('a', '', 'O'), ('mid', '', 'O'), ('-', '', 'O'), ('single', '', 'O'), ('-', '', 'O'), ('digit', '', 'O'), ('million', '', 'O'), ('amount', '', 'O'), ('in', '', 'O'), ('troy', 'ORG', 'B')]
#
# talent saas startup adepto scored £2 million in investment to take off internationally
# Entities [('adepto', 'ORG')]
# Tokens [('talent', '', 'O'), ('saas', '', 'O'), ('startup', '', 'O'), ('adepto', 'ORG', 'B'), ('scored', '', 'O'), ('£', '', 'O'), ('2', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('investment', '', 'O'), ('to', '', 'O'), ('take', '', 'O'), ('off', '', 'O'), ('internationally', '', 'O')]
#
# currencycloud notches approx. £32 million , with more to come
# Entities [('currencycloud', 'ORG')]
# Tokens [('currencycloud', 'ORG', 'B'), ('notches', '', 'O'), ('approx', '', 'O'), ('.', '', 'O'), ('£', '', 'O'), ('32', '', 'O'), ('million', '', 'O'), (',', '', 'O'), ('with', '', 'O'), ('more', '', 'O'), ('to', '', 'O'), ('come', '', 'O')]
#
# dutch edtech startup lessonup receives €350,000  to accelerate growth and to expand abroad
# Entities [('lessonup', 'ORG')]
# Tokens [('dutch', '', 'O'), ('edtech', '', 'O'), ('startup', '', 'O'), ('lessonup', 'ORG', 'B'), ('receives', '', 'O'), ('€', '', 'O'), ('350,000', '', 'O'), (' ', '', 'O'), ('to', '', 'O'), ('accelerate', '', 'O'), ('growth', '', 'O'), ('and', '', 'O'), ('to', '', 'O'), ('expand', '', 'O'), ('abroad', '', 'O')]
#
# tamigo receives €9.3 million  investment from viking venture
# Entities [('tamigo', 'ORG')]
# Tokens [('tamigo', 'ORG', 'B'), ('receives', '', 'O'), ('€', '', 'O'), ('9.3', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('investment', '', 'O'), ('from', '', 'O'), ('viking', '', 'O'), ('venture', '', 'O')]
#
# lisbon proptech startup casafari raises €5 million in round led by lakestar
# Entities [('casafari', 'ORG')]
# Tokens [('lisbon', '', 'O'), ('proptech', '', 'O'), ('startup', '', 'O'), ('casafari', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('round', '', 'O'), ('led', '', 'O'), ('by', '', 'O'), ('lakestar', '', 'O')]
#
# vivet therapeutics receives €45 million  investment from pfizer
# Entities [('vivet therapeutics', 'ORG')]
# Tokens [('vivet', 'ORG', 'B'), ('therapeutics', 'ORG', 'I'), ('receives', '', 'O'), ('€', '', 'O'), ('45', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('investment', '', 'O'), ('from', '', 'O'), ('pfizer', '', 'O')]
#
# restaumatic.com has raised €690,000 in funding
# Entities [('restaumatic.com', 'ORG')]
# Tokens [('restaumatic.com', 'ORG', 'B'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('690,000', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# icelandic startup grid raises $3.5 million to “free the spreadsheet”
# Entities [('grid', 'ORG')]
# Tokens [('icelandic', '', 'O'), ('startup', '', 'O'), ('grid', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('3.5', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('“', '', 'O'), ('free', '', 'O'), ('the', '', 'O'), ('spreadsheet', '', 'O'), ('”', '', 'O')]
#
# wizaplace raises €13 million to export its marketplace solution
# Entities [('wizaplace', 'ORG')]
# Tokens [('wizaplace', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('13', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('export', '', 'O'), ('its', '', 'O'), ('marketplace', '', 'O'), ('solution', '', 'O')]
#
# platforme raises $12 million  in funding
# Entities [('platforme', 'ORG')]
# Tokens [('platforme', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('12', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# belgian startup rombit goes all in on industry 4.0 with €10 million from new investors
# Entities []
# Tokens [('belgian', '', 'O'), ('startup', '', 'O'), ('rombit', '', 'O'), ('goes', '', 'O'), ('all', '', 'O'), ('in', '', 'O'), ('on', '', 'O'), ('industry', '', 'O'), ('4.0', '', 'O'), ('with', '', 'O'), ('€', '', 'O'), ('10', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('new', '', 'O'), ('investors', '', 'O')]
#
# health startup byon8 takes in sek 3 million from existing owners, including luminar ventures
# Entities [('byon8', 'ORG')]
# Tokens [('health', '', 'O'), ('startup', '', 'O'), ('byon8', 'ORG', 'B'), ('takes', '', 'O'), ('in', '', 'O'), ('sek', '', 'O'), ('3', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('existing', '', 'O'), ('owners', '', 'O'), (',', '', 'O'), ('including', '', 'O'), ('luminar', '', 'O'), ('ventures', '', 'O')]
#
# israeli digital adoption co walkme raises $90 million
# Entities [('walkme', 'ORG')]
# Tokens [('israeli', '', 'O'), ('digital', '', 'O'), ('adoption', '', 'O'), ('co', '', 'O'), ('walkme', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('90', '', 'O'), ('million', '', 'O')]
#
# miracle flats comes with €1.6 million
# Entities [('miracle', 'ORG')]
# Tokens [('miracle', 'ORG', 'B'), ('flats', '', 'O'), ('comes', '', 'O'), ('with', '', 'O'), ('€', '', 'O'), ('1.6', '', 'O'), ('million', '', 'O')]
#
# cloud networking co teridion raises $9 million
# Entities [('teridion', 'ORG')]
# Tokens [('cloud', '', 'O'), ('networking', '', 'O'), ('co', '', 'O'), ('teridion', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('9', '', 'O'), ('million', '', 'O')]
#
# scoutbee raises $12 million  in series a funding
# Entities [('scoutbee', 'ORG')]
# Tokens [('scoutbee', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('12', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('funding', '', 'O')]
#
# fintech startup sigmastocks completes a $800,000 investment round
# Entities [('sigmastocks', 'ORG')]
# Tokens [('fintech', '', 'O'), ('startup', '', 'O'), ('sigmastocks', 'ORG', 'B'), ('completes', '', 'O'), ('a', '', 'O'), ('$', '', 'O'), ('800,000', '', 'O'), ('investment', '', 'O'), ('round', '', 'O')]
#
# nightlife app moodie has raised € 550,000
# Entities [('moodie', 'ORG')]
# Tokens [('nightlife', '', 'O'), ('app', '', 'O'), ('moodie', 'ORG', 'B'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('550,000', '', 'O')]
#
# allianz x and debeka invest in the hamburg-based company sda
# Entities [('sda', 'ORG')]
# Tokens [('allianz', '', 'O'), ('x', '', 'O'), ('and', '', 'O'), ('debeka', '', 'O'), ('invest', '', 'O'), ('in', '', 'O'), ('the', '', 'O'), ('hamburg', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('company', '', 'O'), ('sda', 'ORG', 'B')]
#
# paris-based proptech proprioo raises €20 million for its home sales platform
# Entities [('proprioo', 'ORG')]
# Tokens [('paris', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('proptech', '', 'O'), ('proprioo', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('20', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('home', '', 'O'), ('sales', '', 'O'), ('platform', '', 'O')]
#
# mobile security app startup guardsquare raises $29 million from battery ventures and says it has €7m in yearly revenue (andrii degeler/tech.eu)
# Entities [('guardsquare', 'ORG')]
# Tokens [('mobile', '', 'O'), ('security', '', 'O'), ('app', '', 'O'), ('startup', '', 'O'), ('guardsquare', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('29', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('battery', '', 'O'), ('ventures', '', 'O'), ('and', '', 'O'), ('says', '', 'O'), ('it', '', 'O'), ('has', '', 'O'), ('€', '', 'O'), ('7', '', 'O'), ('m', '', 'O'), ('in', '', 'O'), ('yearly', '', 'O'), ('revenue', '', 'O'), ('(', '', 'O'), ('andrii', '', 'O'), ('degeler', '', 'O'), ('/', '', 'O'), ('tech.eu', '', 'O'), (')', '', 'O')]
#
# budbee raises €4.8 million in funding
# Entities [('budbee', 'ORG')]
# Tokens [('budbee', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('4.8', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# l2f raises €2.58 million to disrupt machine learning
# Entities [('l2f', 'ORG')]
# Tokens [('l2f', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('2.58', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('disrupt', '', 'O'), ('machine', '', 'O'), ('learning', '', 'O')]
#
# petsensus, the pet health ecosystem, raises a € 300,000 seed round
# Entities [('petsensus', 'ORG')]
# Tokens [('petsensus', 'ORG', 'B'), (',', '', 'O'), ('the', '', 'O'), ('pet', '', 'O'), ('health', '', 'O'), ('ecosystem', '', 'O'), (',', '', 'O'), ('raises', '', 'O'), ('a', '', 'O'), ('€', '', 'O'), ('300,000', '', 'O'), ('seed', '', 'O'), ('round', '', 'O')]
#
# uk blockchain startup 2030.io raises $3.9 million  with equity tokens via lse’s turquoise test platform
# Entities [('2030.io', 'ORG')]
# Tokens [('uk', '', 'O'), ('blockchain', '', 'O'), ('startup', '', 'O'), ('2030.io', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('3.9', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('with', '', 'O'), ('equity', '', 'O'), ('tokens', '', 'O'), ('via', '', 'O'), ('lse', '', 'O'), ('’s', '', 'O'), ('turquoise', '', 'O'), ('test', '', 'O'), ('platform', '', 'O')]
#
# fortino capital partners invests in declaree, the innovative dutch challenger in expense management
# Entities [('declaree', 'ORG')]
# Tokens [('fortino', '', 'O'), ('capital', '', 'O'), ('partners', '', 'O'), ('invests', '', 'O'), ('in', '', 'O'), ('declaree', 'ORG', 'B'), (',', '', 'O'), ('the', '', 'O'), ('innovative', '', 'O'), ('dutch', '', 'O'), ('challenger', '', 'O'), ('in', '', 'O'), ('expense', '', 'O'), ('management', '', 'O')]
#
# london-based real estate fintech startup immo raises €72 million to accelerate growth
# Entities [('immo', 'ORG')]
# Tokens [('london', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('real', '', 'O'), ('estate', '', 'O'), ('fintech', '', 'O'), ('startup', '', 'O'), ('immo', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('72', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('accelerate', '', 'O'), ('growth', '', 'O')]
#
# computer aided biology pioneer synthace secures $25.6 million in series b funding
# Entities [('computer', 'ORG'), ('synthace', 'ORG')]
# Tokens [('computer', 'ORG', 'B'), ('aided', '', 'O'), ('biology', '', 'O'), ('pioneer', '', 'O'), ('synthace', 'ORG', 'B'), ('secures', '', 'O'), ('$', '', 'O'), ('25.6', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('b', '', 'O'), ('funding', '', 'O')]
#
# russian job search service papajobs raised $ 1 million and changed the business model
# Entities [('papajobs', 'ORG')]
# Tokens [('russian', '', 'O'), ('job', '', 'O'), ('search', '', 'O'), ('service', '', 'O'), ('papajobs', 'ORG', 'B'), ('raised', '', 'O'), ('$', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('and', '', 'O'), ('changed', '', 'O'), ('the', '', 'O'), ('business', '', 'O'), ('model', '', 'O')]
#
# whisbi raises €5 million  in funding
# Entities [('whisbi', 'ORG')]
# Tokens [('whisbi', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# festicket, the festival booking platform, picks up $4.6 million backing from creative investor edge investments
# Entities [('festicket', 'ORG')]
# Tokens [('festicket', 'ORG', 'B'), (',', '', 'O'), ('the', '', 'O'), ('festival', '', 'O'), ('booking', '', 'O'), ('platform', '', 'O'), (',', '', 'O'), ('picks', '', 'O'), ('up', '', 'O'), ('$', '', 'O'), ('4.6', '', 'O'), ('million', '', 'O'), ('backing', '', 'O'), ('from', '', 'O'), ('creative', '', 'O'), ('investor', '', 'O'), ('edge', '', 'O'), ('investments', '', 'O')]
#
# monzo raises £113 million  in series f funding
# Entities [('monzo', 'ORG')]
# Tokens [('monzo', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('113', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('f', '', 'O'), ('funding', '', 'O')]
#
# the fintech inbestme closes a round of financing of €1.3 million
# Entities [('inbestme', 'ORG')]
# Tokens [('the', '', 'O'), ('fintech', '', 'O'), ('inbestme', 'ORG', 'B'), ('closes', '', 'O'), ('a', '', 'O'), ('round', '', 'O'), ('of', '', 'O'), ('financing', '', 'O'), ('of', '', 'O'), ('€', '', 'O'), ('1.3', '', 'O'), ('million', '', 'O')]
#
# nowi just scored €1 million funding to develop a chip for smartwatches and sensors to last forever
# Entities []
# Tokens [('nowi', '', 'O'), ('just', '', 'O'), ('scored', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('funding', '', 'O'), ('to', '', 'O'), ('develop', '', 'O'), ('a', '', 'O'), ('chip', '', 'O'), ('for', '', 'O'), ('smartwatches', '', 'O'), ('and', '', 'O'), ('sensors', '', 'O'), ('to', '', 'O'), ('last', '', 'O'), ('forever', '', 'O')]
#
# london-based snyk accelerates dev-first security with €63 million funding round
# Entities [('snyk', 'ORG')]
# Tokens [('london', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('snyk', 'ORG', 'B'), ('accelerates', '', 'O'), ('dev', '', 'O'), ('-', '', 'O'), ('first', '', 'O'), ('security', '', 'O'), ('with', '', 'O'), ('€', '', 'O'), ('63', '', 'O'), ('million', '', 'O'), ('funding', '', 'O'), ('round', '', 'O')]
#
# softbank's vision fund to invest $440 million in uk online banking startup oaknorth, valuing it at ~$2.8b
# Entities [('oaknorth', 'ORG')]
# Tokens [('softbank', '', 'O'), ("'s", '', 'O'), ('vision', '', 'O'), ('fund', '', 'O'), ('to', '', 'O'), ('invest', '', 'O'), ('$', '', 'O'), ('440', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('uk', '', 'O'), ('online', '', 'O'), ('banking', '', 'O'), ('startup', '', 'O'), ('oaknorth', 'ORG', 'B'), (',', '', 'O'), ('valuing', '', 'O'), ('it', '', 'O'), ('at', '', 'O'), ('~$2.8b', '', 'O')]
#
# london-based cognism raises $10 million in series b to arm sales with ai and conquer asia
# Entities [('cognism', 'ORG')]
# Tokens [('london', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('cognism', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('10', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('b', '', 'O'), ('to', '', 'O'), ('arm', '', 'O'), ('sales', '', 'O'), ('with', '', 'O'), ('ai', '', 'O'), ('and', '', 'O'), ('conquer', '', 'O'), ('asia', '', 'O')]
#
# alsid raises $14.7 million to secure your active directory installation
# Entities [('alsid', 'ORG')]
# Tokens [('alsid', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('14.7', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('secure', '', 'O'), ('your', '', 'O'), ('active', '', 'O'), ('directory', '', 'O'), ('installation', '', 'O')]
#
# doktor.se secured $16 million in a convertible loan
# Entities [('doktor.se', 'ORG')]
# Tokens [('doktor.se', 'ORG', 'B'), ('secured', '', 'O'), ('$', '', 'O'), ('16', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('a', '', 'O'), ('convertible', '', 'O'), ('loan', '', 'O')]
#
# amsterdam-based fintech startup dyme lands €600,000  from peak capital iv’s new fund
# Entities [('dyme', 'ORG')]
# Tokens [('amsterdam', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('fintech', '', 'O'), ('startup', '', 'O'), ('dyme', 'ORG', 'B'), ('lands', '', 'O'), ('€', '', 'O'), ('600,000', '', 'O'), (' ', '', 'O'), ('from', '', 'O'), ('peak', '', 'O'), ('capital', '', 'O'), ('iv', '', 'O'), ('’s', '', 'O'), ('new', '', 'O'), ('fund', '', 'O')]
#
# sidly acquires €805,000 for further development
# Entities [('sidly', 'ORG')]
# Tokens [('sidly', 'ORG', 'B'), ('acquires', '', 'O'), ('€', '', 'O'), ('805,000', '', 'O'), ('for', '', 'O'), ('further', '', 'O'), ('development', '', 'O')]
#
# israeli-founded manufacturing app tulip raises $39.5 million , partners with dmg mori
# Entities [('tulip', 'ORG')]
# Tokens [('israeli', '', 'O'), ('-', '', 'O'), ('founded', '', 'O'), ('manufacturing', '', 'O'), ('app', '', 'O'), ('tulip', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('39.5', '', 'O'), ('million', '', 'O'), (',', '', 'O'), ('partners', '', 'O'), ('with', '', 'O'), ('dmg', '', 'O'), ('mori', '', 'O')]
#
# french ai startup drivetrust raises €1.5 million  funding for a safer driving future
# Entities [('drivetrust', 'ORG')]
# Tokens [('french', '', 'O'), ('ai', '', 'O'), ('startup', '', 'O'), ('drivetrust', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('funding', '', 'O'), ('for', '', 'O'), ('a', '', 'O'), ('safer', '', 'O'), ('driving', '', 'O'), ('future', '', 'O')]
#
# the dr. med. peters group acquires a 25.5% stake in proptech zinsbaustein.de
# Entities [('zinsbaustein.de', 'ORG')]
# Tokens [('the', '', 'O'), ('dr', '', 'O'), ('.', '', 'O'), ('med', '', 'O'), ('.', '', 'O'), ('peters', '', 'O'), ('group', '', 'O'), ('acquires', '', 'O'), ('a', '', 'O'), ('25.5', '', 'O'), ('%', '', 'O'), ('stake', '', 'O'), ('in', '', 'O'), ('proptech', '', 'O'), ('zinsbaustein.de', 'ORG', 'B')]
#
# optellum scores £1 million in funding from luminous ventures to tackle lung cancer diagnosis with ai
# Entities [('optellum', 'ORG')]
# Tokens [('optellum', 'ORG', 'B'), ('scores', '', 'O'), ('£', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O'), ('from', '', 'O'), ('luminous', '', 'O'), ('ventures', '', 'O'), ('to', '', 'O'), ('tackle', '', 'O'), ('lung', '', 'O'), ('cancer', '', 'O'), ('diagnosis', '', 'O'), ('with', '', 'O'), ('ai', '', 'O')]
#
# smartology secures £2.8 million in series a financing
# Entities [('smartology', 'ORG')]
# Tokens [('smartology', 'ORG', 'B'), ('secures', '', 'O'), ('£', '', 'O'), ('2.8', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('financing', '', 'O')]
#
# epti (stockholm, venture builder):  €2.2 million from existing investors
# Entities [('epti', 'ORG')]
# Tokens [('epti', 'ORG', 'B'), ('(', '', 'O'), ('stockholm', '', 'O'), (',', '', 'O'), ('venture', '', 'O'), ('builder', '', 'O'), (')', '', 'O'), (':', '', 'O'), (' ', '', 'O'), ('€', '', 'O'), ('2.2', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('existing', '', 'O'), ('investors', '', 'O')]
#
# hemset has raised €288,000
# Entities [('hemset', 'ORG')]
# Tokens [('hemset', 'ORG', 'B'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('288,000', '', 'O')]
#
# cala raises €1 million  for its vegetarian pasta making robot
# Entities [('cala', 'ORG')]
# Tokens [('cala', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('vegetarian', '', 'O'), ('pasta', '', 'O'), ('making', '', 'O'), ('robot', '', 'O')]
#
# brd raises $15 million in series b funding
# Entities [('brd', 'ORG')]
# Tokens [('brd', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('15', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('b', '', 'O'), ('funding', '', 'O')]
#
# wp invests € 1.77 million in e-podróżnik.pl, teroplan website
# Entities [('e-podróżnik.pl', 'ORG')]
# Tokens [('wp', '', 'O'), ('invests', '', 'O'), ('€', '', 'O'), ('1.77', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('e-podróżnik.pl', 'ORG', 'B'), (',', '', 'O'), ('teroplan', '', 'O'), ('website', '', 'O')]
#
# digitim raises € 1.5 million to manage smartphones and tablets of companies
# Entities [('digitim', 'ORG')]
# Tokens [('digitim', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('manage', '', 'O'), ('smartphones', '', 'O'), ('and', '', 'O'), ('tablets', '', 'O'), ('of', '', 'O'), ('companies', '', 'O')]
#
# insurtech startup lemonade raises $300m, with valuation at reported $2b
# Entities [('lemonade', 'ORG')]
# Tokens [('insurtech', '', 'O'), ('startup', '', 'O'), ('lemonade', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('300', '', 'O'), ('m', '', 'O'), (',', '', 'O'), ('with', '', 'O'), ('valuation', '', 'O'), ('at', '', 'O'), ('reported', '', 'O'), ('$', '', 'O'), ('2b', '', 'O')]
#
# highlife closes a €32 million round b financing
# Entities [('highlife', 'ORG')]
# Tokens [('highlife', 'ORG', 'B'), ('closes', '', 'O'), ('a', '', 'O'), ('€', '', 'O'), ('32', '', 'O'), ('million', '', 'O'), ('round', '', 'O'), ('b', '', 'O'), ('financing', '', 'O')]
#
# bioversys receives a grant of €7 million
# Entities [('bioversys', 'ORG')]
# Tokens [('bioversys', 'ORG', 'B'), ('receives', '', 'O'), ('a', '', 'O'), ('grant', '', 'O'), ('of', '', 'O'), ('€', '', 'O'), ('7', '', 'O'), ('million', '', 'O')]
#
# ultrasoc closes £5 million  equity funding round
# Entities [('ultrasoc', 'ORG')]
# Tokens [('ultrasoc', 'ORG', 'B'), ('closes', '', 'O'), ('£', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('equity', '', 'O'), ('funding', '', 'O'), ('round', '', 'O')]
#
# alarm and crisis management startup serinus raises €1 million from creathor ventures
# Entities [('serinus', 'ORG')]
# Tokens [('alarm', '', 'O'), ('and', '', 'O'), ('crisis', '', 'O'), ('management', '', 'O'), ('startup', '', 'O'), ('serinus', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('creathor', '', 'O'), ('ventures', '', 'O')]
#
# enjoyhq raises $2 million  in seed funding
# Entities [('enjoyhq', 'ORG')]
# Tokens [('enjoyhq', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('2', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('seed', '', 'O'), ('funding', '', 'O')]
#
# carsten maschmeyer invests in berlin health startup thryve
# Entities [('thryve', 'ORG')]
# Tokens [('carsten', '', 'O'), ('maschmeyer', '', 'O'), ('invests', '', 'O'), ('in', '', 'O'), ('berlin', '', 'O'), ('health', '', 'O'), ('startup', '', 'O'), ('thryve', 'ORG', 'B')]
#
# liva healthcare has raised € 7.8 million from german vc funds
# Entities [('liva healthcare', 'ORG')]
# Tokens [('liva', 'ORG', 'B'), ('healthcare', 'ORG', 'I'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('7.8', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('german', '', 'O'), ('vc', '', 'O'), ('funds', '', 'O')]
#
# rfrnz raises seven-figure funding round
# Entities [('rfrnz', 'ORG')]
# Tokens [('rfrnz', 'ORG', 'B'), ('raises', '', 'O'), ('seven', '', 'O'), ('-', '', 'O'), ('figure', '', 'O'), ('funding', '', 'O'), ('round', '', 'O')]
#
# the electrospinning company secures £1.5 million  in series a funding
# Entities [('electrospinning', 'ORG')]
# Tokens [('the', '', 'O'), ('electrospinning', 'ORG', 'B'), ('company', '', 'O'), ('secures', '', 'O'), ('£', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('funding', '', 'O')]
#
# berlin-based coachhub raises €6 million to scale its digital coaching technology
# Entities [('coachhub', 'ORG')]
# Tokens [('berlin', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('coachhub', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('6', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('scale', '', 'O'), ('its', '', 'O'), ('digital', '', 'O'), ('coaching', '', 'O'), ('technology', '', 'O')]
#
# connected car platform eccocar raised €495,000 from grupo valgine, cmc xxi, pinama, xesgalicia and vigo activo
# Entities [('eccocar', 'ORG')]
# Tokens [('connected', '', 'O'), ('car', '', 'O'), ('platform', '', 'O'), ('eccocar', 'ORG', 'B'), ('raised', '', 'O'), ('€', '', 'O'), ('495,000', '', 'O'), ('from', '', 'O'), ('grupo', '', 'O'), ('valgine', '', 'O'), (',', '', 'O'), ('cmc', '', 'O'), ('xxi', '', 'O'), (',', '', 'O'), ('pinama', '', 'O'), (',', '', 'O'), ('xesgalicia', '', 'O'), ('and', '', 'O'), ('vigo', '', 'O'), ('activo', '', 'O')]
#
# bergen carbon solutions has raised € 1.65 million
# Entities [('bergen carbon solutions', 'ORG')]
# Tokens [('bergen', 'ORG', 'B'), ('carbon', 'ORG', 'I'), ('solutions', 'ORG', 'I'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('1.65', '', 'O'), ('million', '', 'O')]
#
# softbank invests €900 million in germany’s wirecard
# Entities [('wirecard', 'ORG')]
# Tokens [('softbank', '', 'O'), ('invests', '', 'O'), ('€', '', 'O'), ('900', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('germany', '', 'O'), ('’s', '', 'O'), ('wirecard', 'ORG', 'B')]
#
# memmo (stockholm, provider of personalised greeting messages from celebrities): €2 million from luxor capital and angel investors
# Entities [('memmo', 'ORG')]
# Tokens [('memmo', 'ORG', 'B'), ('(', '', 'O'), ('stockholm', '', 'O'), (',', '', 'O'), ('provider', '', 'O'), ('of', '', 'O'), ('personalised', '', 'O'), ('greeting', '', 'O'), ('messages', '', 'O'), ('from', '', 'O'), ('celebrities', '', 'O'), (')', '', 'O'), (':', '', 'O'), ('€', '', 'O'), ('2', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('luxor', '', 'O'), ('capital', '', 'O'), ('and', '', 'O'), ('angel', '', 'O'), ('investors', '', 'O')]
#
# remote driving co phantom auto raises $13.5 million
# Entities [('phantom auto', 'ORG')]
# Tokens [('remote', '', 'O'), ('driving', '', 'O'), ('co', '', 'O'), ('phantom', 'ORG', 'B'), ('auto', 'ORG', 'I'), ('raises', '', 'O'), ('$', '', 'O'), ('13.5', '', 'O'), ('million', '', 'O')]
#
# london-based rapyd, a fintech-as-a-service platform, raises a further €18 million
# Entities [('rapyd', 'ORG')]
# Tokens [('london', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('rapyd', 'ORG', 'B'), (',', '', 'O'), ('a', '', 'O'), ('fintech', '', 'O'), ('-', '', 'O'), ('as', '', 'O'), ('-', '', 'O'), ('a', '', 'O'), ('-', '', 'O'), ('service', '', 'O'), ('platform', '', 'O'), (',', '', 'O'), ('raises', '', 'O'), ('a', '', 'O'), ('further', '', 'O'), ('€', '', 'O'), ('18', '', 'O'), ('million', '', 'O')]
#
# trucksters gets € 250,000 of funding
# Entities [('trucksters', 'ORG')]
# Tokens [('trucksters', 'ORG', 'B'), ('gets', '', 'O'), ('€', '', 'O'), ('250,000', '', 'O'), ('of', '', 'O'), ('funding', '', 'O')]
#
# sek ventures invest in shyftplan
# Entities [('shyftplan', 'ORG')]
# Tokens [('sek', '', 'O'), ('ventures', '', 'O'), ('invest', '', 'O'), ('in', '', 'O'), ('shyftplan', 'ORG', 'B')]
#
# hefring marine raises an undisclosed amount from new business venture fund
# Entities [('hefring marine', 'ORG')]
# Tokens [('hefring', 'ORG', 'B'), ('marine', 'ORG', 'I'), ('raises', '', 'O'), ('an', '', 'O'), ('undisclosed', '', 'O'), ('amount', '', 'O'), ('from', '', 'O'), ('new', '', 'O'), ('business', '', 'O'), ('venture', '', 'O'), ('fund', '', 'O')]
#
# smart parking startup communithings lands €3 million from orange and others
# Entities [('communithings', 'ORG')]
# Tokens [('smart', '', 'O'), ('parking', '', 'O'), ('startup', '', 'O'), ('communithings', 'ORG', 'B'), ('lands', '', 'O'), ('€', '', 'O'), ('3', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('orange', '', 'O'), ('and', '', 'O'), ('others', '', 'O')]
#
# enterprise analytics startup avora secures $6.5 million
# Entities [('avora', 'ORG')]
# Tokens [('enterprise', '', 'O'), ('analytics', '', 'O'), ('startup', '', 'O'), ('avora', 'ORG', 'B'), ('secures', '', 'O'), ('$', '', 'O'), ('6.5', '', 'O'), ('million', '', 'O')]
#
# swiss financial investors invest € 8.6 million francs in evolute
# Entities [('evolute', 'ORG')]
# Tokens [('swiss', '', 'O'), ('financial', '', 'O'), ('investors', '', 'O'), ('invest', '', 'O'), ('€', '', 'O'), ('8.6', '', 'O'), ('million', '', 'O'), ('francs', '', 'O'), ('in', '', 'O'), ('evolute', 'ORG', 'B')]
#
# gloat gathers $25 million to help enterprise develop internal talent and build “future-proof workforces”
# Entities []
# Tokens [('gloat', '', 'O'), ('gathers', '', 'O'), ('$', '', 'O'), ('25', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('help', '', 'O'), ('enterprise', '', 'O'), ('develop', '', 'O'), ('internal', '', 'O'), ('talent', '', 'O'), ('and', '', 'O'), ('build', '', 'O'), ('“', '', 'O'), ('future', '', 'O'), ('-', '', 'O'), ('proof', '', 'O'), ('workforces', '', 'O'), ('”', '', 'O')]
#
# london’s sportside raises £400,000 from fortunis capital for its ‘tinder for sports’
# Entities [('sportside', 'ORG')]
# Tokens [('london', '', 'O'), ('’s', '', 'O'), ('sportside', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('400,000', '', 'O'), ('from', '', 'O'), ('fortunis', '', 'O'), ('capital', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('‘', '', 'O'), ('tinder', '', 'O'), ('for', '', 'O'), ('sports', '', 'O'), ('’', '', 'O')]
#
# digital sleep treatment startup learning to sleep raises €1 million to launch in the uk
# Entities [('learning to sleep', 'ORG')]
# Tokens [('digital', '', 'O'), ('sleep', '', 'O'), ('treatment', '', 'O'), ('startup', '', 'O'), ('learning', 'ORG', 'B'), ('to', 'ORG', 'I'), ('sleep', 'ORG', 'I'), ('raises', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('launch', '', 'O'), ('in', '', 'O'), ('the', '', 'O'), ('uk', '', 'O')]
#
# anna money raises £8.5 million in funding
# Entities [('anna', 'ORG')]
# Tokens [('anna', 'ORG', 'B'), ('money', '', 'O'), ('raises', '', 'O'), ('£', '', 'O'), ('8.5', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# f&a forecasting has raised €211,200 from a number of prominent angels
# Entities [('f&a forecasting', 'ORG')]
# Tokens [('f&a', 'ORG', 'B'), ('forecasting', 'ORG', 'I'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('211,200', '', 'O'), ('from', '', 'O'), ('a', '', 'O'), ('number', '', 'O'), ('of', '', 'O'), ('prominent', '', 'O'), ('angels', '', 'O')]
#
# capnamic invests € 3 million in aifora
# Entities [('aifora', 'ORG')]
# Tokens [('capnamic', '', 'O'), ('invests', '', 'O'), ('€', '', 'O'), ('3', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('aifora', 'ORG', 'B')]
#
# sense biodetection raises £12.3 million  in funding
# Entities [('biodetection', 'ORG')]
# Tokens [('sense', '', 'O'), ('biodetection', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('12.3', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# game studio redhill games has raised $11.4 million led by makers fund
# Entities [('game studio', 'ORG')]
# Tokens [('game', 'ORG', 'B'), ('studio', 'ORG', 'I'), ('redhill', '', 'O'), ('games', '', 'O'), ('has', '', 'O'), ('raised', '', 'O'), ('$', '', 'O'), ('11.4', '', 'O'), ('million', '', 'O'), ('led', '', 'O'), ('by', '', 'O'), ('makers', '', 'O'), ('fund', '', 'O')]
#
# zynapp has raised € 3.84 million so far
# Entities [('zynapp', 'ORG')]
# Tokens [('zynapp', 'ORG', 'B'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('3.84', '', 'O'), ('million', '', 'O'), ('so', '', 'O'), ('far', '', 'O')]
#
# london-based fintech startup hokodo awarded €2 million by horizon 2020 to free smes from unpaid invoices
# Entities [('hokodo', 'ORG')]
# Tokens [('london', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('fintech', '', 'O'), ('startup', '', 'O'), ('hokodo', 'ORG', 'B'), ('awarded', '', 'O'), ('€', '', 'O'), ('2', '', 'O'), ('million', '', 'O'), ('by', '', 'O'), ('horizon', '', 'O'), ('2020', '', 'O'), ('to', '', 'O'), ('free', '', 'O'), ('smes', '', 'O'), ('from', '', 'O'), ('unpaid', '', 'O'), ('invoices', '', 'O')]
#
# strapi raises $4 million  in seed funding
# Entities [('strapi', 'ORG')]
# Tokens [('strapi', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('4', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('seed', '', 'O'), ('funding', '', 'O')]
#
# startup brainscan raised $ 1 million from the national center for research and development
# Entities [('brainscan', 'ORG')]
# Tokens [('startup', '', 'O'), ('brainscan', 'ORG', 'B'), ('raised', '', 'O'), ('$', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('the', '', 'O'), ('national', '', 'O'), ('center', '', 'O'), ('for', '', 'O'), ('research', '', 'O'), ('and', '', 'O'), ('development', '', 'O')]
#
# whispr raises $750000 for its ai-based voice guidance system for workers
# Entities [('whispr', 'ORG')]
# Tokens [('whispr', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('750000', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('ai', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('voice', '', 'O'), ('guidance', '', 'O'), ('system', '', 'O'), ('for', '', 'O'), ('workers', '', 'O')]
#
# málaga-based predictiva raises €2.6 million for its ai solution to analyze customer service and sales calls
# Entities [('predictiva', 'ORG')]
# Tokens [('málaga', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('predictiva', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('2.6', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('ai', '', 'O'), ('solution', '', 'O'), ('to', '', 'O'), ('analyze', '', 'O'), ('customer', '', 'O'), ('service', '', 'O'), ('and', '', 'O'), ('sales', '', 'O'), ('calls', '', 'O')]
#
# social impact startup tykn raises €1.2 million for its blockchain platform to verify the identities of world’s ‘invisible people’
# Entities [('tykn', 'ORG')]
# Tokens [('social', '', 'O'), ('impact', '', 'O'), ('startup', '', 'O'), ('tykn', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.2', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('blockchain', '', 'O'), ('platform', '', 'O'), ('to', '', 'O'), ('verify', '', 'O'), ('the', '', 'O'), ('identities', '', 'O'), ('of', '', 'O'), ('world', '', 'O'), ('’s', '', 'O'), ('‘', '', 'O'), ('invisible', '', 'O'), ('people', '', 'O'), ('’', '', 'O')]
#
# health startup alex has raised € 393,600
# Entities [('alex', 'ORG')]
# Tokens [('health', '', 'O'), ('startup', '', 'O'), ('alex', 'ORG', 'B'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('393,600', '', 'O')]
#
# teralytics raises $17.5 million, ai tech startup deepcode scores $4 million
# Entities [('teralytics', 'ORG')]
# Tokens [('teralytics', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('17.5', '', 'O'), ('million', '', 'O'), (',', '', 'O'), ('ai', '', 'O'), ('tech', '', 'O'), ('startup', '', 'O'), ('deepcode', '', 'O'), ('scores', '', 'O'), ('$', '', 'O'), ('4', '', 'O'), ('million', '', 'O')]
#
# onemind dogs raises € 513,900
# Entities [('onemind dogs', 'ORG')]
# Tokens [('onemind', 'ORG', 'B'), ('dogs', 'ORG', 'I'), ('raises', '', 'O'), ('€', '', 'O'), ('513,900', '', 'O')]
#
# growth intelligence raises £1.7 million in funding
# Entities [('growth intelligence', 'ORG')]
# Tokens [('growth', 'ORG', 'B'), ('intelligence', 'ORG', 'I'), ('raises', '', 'O'), ('£', '', 'O'), ('1.7', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# airship raises £500,000  in funding
# Entities [('airship', 'ORG')]
# Tokens [('airship', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('500,000', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# update: finnish clean energy company wello surpasses €1.5 million during final days on invesdor
# Entities [('wello', 'ORG')]
# Tokens [('update', '', 'O'), (':', '', 'O'), ('finnish', '', 'O'), ('clean', '', 'O'), ('energy', '', 'O'), ('company', '', 'O'), ('wello', 'ORG', 'B'), ('surpasses', '', 'O'), ('€', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), ('during', '', 'O'), ('final', '', 'O'), ('days', '', 'O'), ('on', '', 'O'), ('invesdor', '', 'O')]
#
# biopharma company wren therapeutics inks series a
# Entities [('wren therapeutics', 'ORG')]
# Tokens [('biopharma', '', 'O'), ('company', '', 'O'), ('wren', 'ORG', 'B'), ('therapeutics', 'ORG', 'I'), ('inks', '', 'O'), ('series', '', 'O'), ('a', '', 'O')]
#
# treefrog therapeutics raises € 7.1 million
# Entities [('treefrog therapeutics', 'ORG')]
# Tokens [('treefrog', 'ORG', 'B'), ('therapeutics', 'ORG', 'I'), ('raises', '', 'O'), ('€', '', 'O'), ('7.1', '', 'O'), ('million', '', 'O')]
#
# moodify raises $1.6 million  in funding
# Entities [('moodify', 'ORG')]
# Tokens [('moodify', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('1.6', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# australian supermarket chain buys a spoon at marley spoon
# Entities [('chain', 'ORG')]
# Tokens [('australian', '', 'O'), ('supermarket', '', 'O'), ('chain', 'ORG', 'B'), ('buys', '', 'O'), ('a', '', 'O'), ('spoon', '', 'O'), ('at', '', 'O'), ('marley', '', 'O'), ('spoon', '', 'O')]
#
# merito raises € 1 million for its recruitment platform dedicated to retailers
# Entities [('merito', 'ORG')]
# Tokens [('merito', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('recruitment', '', 'O'), ('platform', '', 'O'), ('dedicated', '', 'O'), ('to', '', 'O'), ('retailers', '', 'O')]
#
# sports apparel giant asics invested in valencia-based new materials company pyrates smart fabrics
# Entities [('pyrates smart fabrics', 'ORG')]
# Tokens [('sports', '', 'O'), ('apparel', '', 'O'), ('giant', '', 'O'), ('asics', '', 'O'), ('invested', '', 'O'), ('in', '', 'O'), ('valencia', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('new', '', 'O'), ('materials', '', 'O'), ('company', '', 'O'), ('pyrates', 'ORG', 'B'), ('smart', 'ORG', 'I'), ('fabrics', 'ORG', 'I')]
#
# trint raises us$4.5 million in funding
# Entities [('trint', 'ORG')]
# Tokens [('trint', 'ORG', 'B'), ('raises', '', 'O'), ('us$4.5', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# madrid-based fintech startup micappital raised €750,000
# Entities [('micappital', 'ORG')]
# Tokens [('madrid', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('fintech', '', 'O'), ('startup', '', 'O'), ('micappital', 'ORG', 'B'), ('raised', '', 'O'), ('€', '', 'O'), ('750,000', '', 'O')]
#
# serstech (lund, developer of chemical intelligence solutions): €2.3 million  through a guaranteed rights issue
# Entities [('lund', 'ORG')]
# Tokens [('serstech', '', 'O'), ('(', '', 'O'), ('lund', 'ORG', 'B'), (',', '', 'O'), ('developer', '', 'O'), ('of', '', 'O'), ('chemical', '', 'O'), ('intelligence', '', 'O'), ('solutions', '', 'O'), (')', '', 'O'), (':', '', 'O'), ('€', '', 'O'), ('2.3', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('through', '', 'O'), ('a', '', 'O'), ('guaranteed', '', 'O'), ('rights', '', 'O'), ('issue', '', 'O')]
#
# playworks scores funding
# Entities [('playworks', 'ORG')]
# Tokens [('playworks', 'ORG', 'B'), ('scores', '', 'O'), ('funding', '', 'O')]
#
# norwegian startup inzpire.me scores €1.2 million to expand its influencer marketing platform
# Entities [('inzpire.me', 'ORG')]
# Tokens [('norwegian', '', 'O'), ('startup', '', 'O'), ('inzpire.me', 'ORG', 'B'), ('scores', '', 'O'), ('€', '', 'O'), ('1.2', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('expand', '', 'O'), ('its', '', 'O'), ('influencer', '', 'O'), ('marketing', '', 'O'), ('platform', '', 'O')]
#
# algrano obtains additional €3.44 million to digitalize the coffee industry
# Entities [('algrano', 'ORG')]
# Tokens [('algrano', 'ORG', 'B'), ('obtains', '', 'O'), ('additional', '', 'O'), ('€', '', 'O'), ('3.44', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('digitalize', '', 'O'), ('the', '', 'O'), ('coffee', '', 'O'), ('industry', '', 'O')]
#
# epiendo pharmaceuticals raise €800000 to advance their treatments for respiratory diseases
# Entities [('epiendo pharmaceuticals', 'ORG')]
# Tokens [('epiendo', 'ORG', 'B'), ('pharmaceuticals', 'ORG', 'I'), ('raise', '', 'O'), ('€', '', 'O'), ('800000', '', 'O'), ('to', '', 'O'), ('advance', '', 'O'), ('their', '', 'O'), ('treatments', '', 'O'), ('for', '', 'O'), ('respiratory', '', 'O'), ('diseases', '', 'O')]
#
# nantes-based akeneo raises €41 million to further develop its product experience management platform
# Entities [('akeneo', 'ORG')]
# Tokens [('nantes', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('akeneo', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('41', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('further', '', 'O'), ('develop', '', 'O'), ('its', '', 'O'), ('product', '', 'O'), ('experience', '', 'O'), ('management', '', 'O'), ('platform', '', 'O')]
#
# geckolabs raises £1.8 million  in funding
# Entities [('geckolabs', 'ORG')]
# Tokens [('geckolabs', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('1.8', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# safe365 closes a round of € 1 million led by mangrove capital
# Entities [('safe365', 'ORG')]
# Tokens [('safe365', 'ORG', 'B'), ('closes', '', 'O'), ('a', '', 'O'), ('round', '', 'O'), ('of', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('led', '', 'O'), ('by', '', 'O'), ('mangrove', '', 'O'), ('capital', '', 'O')]
#
# fieldly raises €1.5 million  and appoints new ceo
# Entities [('fieldly', 'ORG')]
# Tokens [('fieldly', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('and', '', 'O'), ('appoints', '', 'O'), ('new', '', 'O'), ('ceo', '', 'O')]
#
# seb has invested in (secondaries) digital accounting startup pe accounting
# Entities [('pe accounting', 'ORG')]
# Tokens [('seb', '', 'O'), ('has', '', 'O'), ('invested', '', 'O'), ('in', '', 'O'), ('(', '', 'O'), ('secondaries', '', 'O'), (')', '', 'O'), ('digital', '', 'O'), ('accounting', '', 'O'), ('startup', '', 'O'), ('pe', 'ORG', 'B'), ('accounting', 'ORG', 'I')]
#
# vienna-based contextflow gmbh raises funding for its image recognition tech for radiologists
# Entities [('contextflow', 'ORG')]
# Tokens [('vienna', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('contextflow', 'ORG', 'B'), ('gmbh', '', 'O'), ('raises', '', 'O'), ('funding', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('image', '', 'O'), ('recognition', '', 'O'), ('tech', '', 'O'), ('for', '', 'O'), ('radiologists', '', 'O')]
#
# seven ventures invests in movinga
# Entities [('movinga', 'ORG')]
# Tokens [('seven', '', 'O'), ('ventures', '', 'O'), ('invests', '', 'O'), ('in', '', 'O'), ('movinga', 'ORG', 'B')]
#
# asturias-based startup singularprice raised funding
# Entities [('singularprice', 'ORG')]
# Tokens [('asturias', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('startup', '', 'O'), ('singularprice', 'ORG', 'B'), ('raised', '', 'O'), ('funding', '', 'O')]
#
# medical ai startup aidence raises €10 million
# Entities [('aidence', 'ORG')]
# Tokens [('medical', '', 'O'), ('ai', '', 'O'), ('startup', '', 'O'), ('aidence', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('10', '', 'O'), ('million', '', 'O')]
#
# kinnevik invests €86 million in online grocery store mathem, upping its stake to 38%
# Entities [('mathem', 'ORG')]
# Tokens [('kinnevik', '', 'O'), ('invests', '', 'O'), ('€', '', 'O'), ('86', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('online', '', 'O'), ('grocery', '', 'O'), ('store', '', 'O'), ('mathem', 'ORG', 'B'), (',', '', 'O'), ('upping', '', 'O'), ('its', '', 'O'), ('stake', '', 'O'), ('to', '', 'O'), ('38', '', 'O'), ('%', '', 'O')]
#
# fishtripr raises €500000 for its sports fishing marketplace
# Entities [('fishtripr', 'ORG')]
# Tokens [('fishtripr', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('500000', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('sports', '', 'O'), ('fishing', '', 'O'), ('marketplace', '', 'O')]
#
# feast it raises £1.7 million funding round by coldplay member and dragons' den sarah willingham
# Entities [('feast', 'ORG')]
# Tokens [('feast', 'ORG', 'B'), ('it', '', 'O'), ('raises', '', 'O'), ('£', '', 'O'), ('1.7', '', 'O'), ('million', '', 'O'), ('funding', '', 'O'), ('round', '', 'O'), ('by', '', 'O'), ('coldplay', '', 'O'), ('member', '', 'O'), ('and', '', 'O'), ('dragons', '', 'O'), ("'", '', 'O'), ('den', '', 'O'), ('sarah', '', 'O'), ('willingham', '', 'O')]
#
# epc raises € 1.5 million to digitize champagne
# Entities [('epc', 'ORG')]
# Tokens [('epc', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('digitize', '', 'O'), ('champagne', '', 'O')]
#
# herry ventures and 42cap invest an unknown amount in  cioplenu
# Entities [('cioplenu', 'ORG')]
# Tokens [('herry', '', 'O'), ('ventures', '', 'O'), ('and', '', 'O'), ('42cap', '', 'O'), ('invest', '', 'O'), ('an', '', 'O'), ('unknown', '', 'O'), ('amount', '', 'O'), ('in', '', 'O'), (' ', '', 'O'), ('cioplenu', 'ORG', 'B')]
#
# attest raises $16 million in series a funding
# Entities [('attest', 'ORG')]
# Tokens [('attest', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('16', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('funding', '', 'O')]
#
# freeda raises another $16 million for its media brand for women
# Entities [('freeda', 'ORG')]
# Tokens [('freeda', 'ORG', 'B'), ('raises', '', 'O'), ('another', '', 'O'), ('$', '', 'O'), ('16', '', 'O'), ('million', '', 'O'), ('for', '', 'O'), ('its', '', 'O'), ('media', '', 'O'), ('brand', '', 'O'), ('for', '', 'O'), ('women', '', 'O')]
#
# ...
#
# itch raises £5 million  in funding
# Entities [('itch', 'ORG')]
# Tokens [('itch', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# retailers saas co donde search raises $6.5 million
# Entities [('donde search', 'ORG')]
# Tokens [('retailers', '', 'O'), ('saas', '', 'O'), ('co', '', 'O'), ('donde', 'ORG', 'B'), ('search', 'ORG', 'I'), ('raises', '', 'O'), ('$', '', 'O'), ('6.5', '', 'O'), ('million', '', 'O')]
#
# capacura and ibb beteiligungsgesellschaft are investing an undisclosed amount in berliner krankenhausendienst krankenhaus.de
# Entities [('krankenhaus.de', 'ORG')]
# Tokens [('capacura', '', 'O'), ('and', '', 'O'), ('ibb', '', 'O'), ('beteiligungsgesellschaft', '', 'O'), ('are', '', 'O'), ('investing', '', 'O'), ('an', '', 'O'), ('undisclosed', '', 'O'), ('amount', '', 'O'), ('in', '', 'O'), ('berliner', '', 'O'), ('krankenhausendienst', '', 'O'), ('krankenhaus.de', 'ORG', 'B')]
#
# mirdetect raises seven-digit seed funding
# Entities [('mirdetect', 'ORG')]
# Tokens [('mirdetect', 'ORG', 'B'), ('raises', '', 'O'), ('seven', '', 'O'), ('-', '', 'O'), ('digit', '', 'O'), ('seed', '', 'O'), ('funding', '', 'O')]
#
# delft-based mobility startup scoozy raises €1.2 million  funding: here's all you need to know about their innovative electric scooters
# Entities [('scoozy', 'ORG')]
# Tokens [('delft', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('mobility', '', 'O'), ('startup', '', 'O'), ('scoozy', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('1.2', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('funding', '', 'O'), (':', '', 'O'), ('here', '', 'O'), ("'s", '', 'O'), ('all', '', 'O'), ('you', '', 'O'), ('need', '', 'O'), ('to', '', 'O'), ('know', '', 'O'), ('about', '', 'O'), ('their', '', 'O'), ('innovative', '', 'O'), ('electric', '', 'O'), ('scooters', '', 'O')]
#
# avectas raises $10 million in equity funding
# Entities [('avectas', 'ORG')]
# Tokens [('avectas', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('10', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('equity', '', 'O'), ('funding', '', 'O')]
#
# addressya are soon setting out to raise € 672,000
# Entities [('addressya are soon', 'ORG')]
# Tokens [('addressya', 'ORG', 'B'), ('are', 'ORG', 'I'), ('soon', 'ORG', 'I'), ('setting', '', 'O'), ('out', '', 'O'), ('to', '', 'O'), ('raise', '', 'O'), ('€', '', 'O'), ('672,000', '', 'O')]
#
# insurance chatbot startup leo raises $1.6 million
# Entities [('leo', 'ORG')]
# Tokens [('insurance', '', 'O'), ('chatbot', '', 'O'), ('startup', '', 'O'), ('leo', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('1.6', '', 'O'), ('million', '', 'O')]
#
# digital belgium skills fund invests € 230,000 in workshops fyxxi in ghent
# Entities [('ghent', 'ORG')]
# Tokens [('digital', '', 'O'), ('belgium', '', 'O'), ('skills', '', 'O'), ('fund', '', 'O'), ('invests', '', 'O'), ('€', '', 'O'), ('230,000', '', 'O'), ('in', '', 'O'), ('workshops', '', 'O'), ('fyxxi', '', 'O'), ('in', '', 'O'), ('ghent', 'ORG', 'B')]
#
# frontastic includes pre-series a over €1.8 million
# Entities []
# Tokens [('frontastic', '', 'O'), ('includes', '', 'O'), ('pre', '', 'O'), ('-', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('over', '', 'O'), ('€', '', 'O'), ('1.8', '', 'O'), ('million', '', 'O')]
#
# dfs takes leading position in the utm world by investing in unifly
# Entities [('dfs', 'ORG')]
# Tokens [('dfs', 'ORG', 'B'), ('takes', '', 'O'), ('leading', '', 'O'), ('position', '', 'O'), ('in', '', 'O'), ('the', '', 'O'), ('utm', '', 'O'), ('world', '', 'O'), ('by', '', 'O'), ('investing', '', 'O'), ('in', '', 'O'), ('unifly', '', 'O')]
#
# french customer care chatbot startup mindsay raises $10 million
# Entities [('mindsay', 'ORG')]
# Tokens [('french', '', 'O'), ('customer', '', 'O'), ('care', '', 'O'), ('chatbot', '', 'O'), ('startup', '', 'O'), ('mindsay', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('10', '', 'O'), ('million', '', 'O')]
#
# mainstreaming secures $6 million funding
# Entities [('mainstreaming', 'ORG')]
# Tokens [('mainstreaming', 'ORG', 'B'), ('secures', '', 'O'), ('$', '', 'O'), ('6', '', 'O'), ('million', '', 'O'), ('funding', '', 'O')]
#
# cynerio secures $7 million seed funding
# Entities [('cynerio', 'ORG')]
# Tokens [('cynerio', 'ORG', 'B'), ('secures', '', 'O'), ('$', '', 'O'), ('7', '', 'O'), ('million', '', 'O'), ('seed', '', 'O'), ('funding', '', 'O')]
#
# russian video-on-demand service ivi raises $40 million
# Entities [('ivi', 'ORG')]
# Tokens [('russian', '', 'O'), ('video', '', 'O'), ('-', '', 'O'), ('on', '', 'O'), ('-', '', 'O'), ('demand', '', 'O'), ('service', '', 'O'), ('ivi', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('40', '', 'O'), ('million', '', 'O')]
#
# tampere-based wirepas raises €14.4 million to build iiot and iot connectivity on a massive scale
# Entities [('wirepas', 'ORG')]
# Tokens [('tampere', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('wirepas', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('14.4', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('build', '', 'O'), ('iiot', '', 'O'), ('and', '', 'O'), ('iot', '', 'O'), ('connectivity', '', 'O'), ('on', '', 'O'), ('a', '', 'O'), ('massive', '', 'O'), ('scale', '', 'O')]
#
# kovrr raises $5.5 million  in funding
# Entities [('kovrr', 'ORG')]
# Tokens [('kovrr', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('5.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# french legaltech startup hyperlex raises €4 million
# Entities [('hyperlex', 'ORG')]
# Tokens [('french', '', 'O'), ('legaltech', '', 'O'), ('startup', '', 'O'), ('hyperlex', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('4', '', 'O'), ('million', '', 'O')]
#
# agritech startup agerpix raised €270,000
# Entities [('agerpix', 'ORG')]
# Tokens [('agritech', '', 'O'), ('startup', '', 'O'), ('agerpix', 'ORG', 'B'), ('raised', '', 'O'), ('€', '', 'O'), ('270,000', '', 'O')]
#
# swedish electric motorcycle company cake takes in €12.96 million
# Entities [('cake', 'ORG')]
# Tokens [('swedish', '', 'O'), ('electric', '', 'O'), ('motorcycle', '', 'O'), ('company', '', 'O'), ('cake', 'ORG', 'B'), ('takes', '', 'O'), ('in', '', 'O'), ('€', '', 'O'), ('12.96', '', 'O'), ('million', '', 'O')]
#
# israeli healthcare data engine firm mdclone raises $26 million
# Entities [('mdclone', 'ORG')]
# Tokens [('israeli', '', 'O'), ('healthcare', '', 'O'), ('data', '', 'O'), ('engine', '', 'O'), ('firm', '', 'O'), ('mdclone', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('26', '', 'O'), ('million', '', 'O')]
#
# snabbus gets € 1 million to coaches for rent
# Entities [('snabbus', 'ORG')]
# Tokens [('snabbus', 'ORG', 'B'), ('gets', '', 'O'), ('€', '', 'O'), ('1', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('coaches', '', 'O'), ('for', '', 'O'), ('rent', '', 'O')]
#
# tastewise raises $5 million  in series a funding
# Entities [('tastewise', 'ORG')]
# Tokens [('tastewise', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('funding', '', 'O')]
#
# manual raises £5 million to build its well-being guide for men
# Entities [('manual', 'ORG')]
# Tokens [('manual', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('5', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('build', '', 'O'), ('its', '', 'O'), ('well', '', 'O'), ('-', '', 'O'), ('being', '', 'O'), ('guide', '', 'O'), ('for', '', 'O'), ('men', '', 'O')]
#
# online games platform genba digital surpasses £525,000 on syndicateroom
# Entities [('genba digital', 'ORG')]
# Tokens [('online', '', 'O'), ('games', '', 'O'), ('platform', '', 'O'), ('genba', 'ORG', 'B'), ('digital', 'ORG', 'I'), ('surpasses', '', 'O'), ('£', '', 'O'), ('525,000', '', 'O'), ('on', '', 'O'), ('syndicateroom', '', 'O')]
#
# tidio raises pln 4 million from inovo venture partners at €920,000
# Entities [('tidio', 'ORG')]
# Tokens [('tidio', 'ORG', 'B'), ('raises', '', 'O'), ('pln', '', 'O'), ('4', '', 'O'), ('million', '', 'O'), ('from', '', 'O'), ('inovo', '', 'O'), ('venture', '', 'O'), ('partners', '', 'O'), ('at', '', 'O'), ('€', '', 'O'), ('920,000', '', 'O')]
#
# digital marketing assistant for restaurants ‘tilde’ has raised €260,000
# Entities []
# Tokens [('digital', '', 'O'), ('marketing', '', 'O'), ('assistant', '', 'O'), ('for', '', 'O'), ('restaurants', '', 'O'), ('‘', '', 'O'), ('tilde', '', 'O'), ('’', '', 'O'), ('has', '', 'O'), ('raised', '', 'O'), ('€', '', 'O'), ('260,000', '', 'O')]
#
# brigitte zypries, federal minister of economics and energy (retired), is investing in the berlin startup motor ai
# Entities [('brigitte zypries', 'ORG'), ('economics', 'ORG')]
# Tokens [('brigitte', 'ORG', 'B'), ('zypries', 'ORG', 'I'), (',', '', 'O'), ('federal', '', 'O'), ('minister', '', 'O'), ('of', '', 'O'), ('economics', 'ORG', 'B'), ('and', '', 'O'), ('energy', '', 'O'), ('(', '', 'O'), ('retired', '', 'O'), (')', '', 'O'), (',', '', 'O'), ('is', '', 'O'), ('investing', '', 'O'), ('in', '', 'O'), ('the', '', 'O'), ('berlin', '', 'O'), ('startup', '', 'O'), ('motor', '', 'O'), ('ai', '', 'O')]
#
# transport management startup supplystack raises €5 million
# Entities [('supplystack', 'ORG')]
# Tokens [('transport', '', 'O'), ('management', '', 'O'), ('startup', '', 'O'), ('supplystack', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('5', '', 'O'), ('million', '', 'O')]
#
# apifix closes series b financing
# Entities [('apifix', 'ORG')]
# Tokens [('apifix', 'ORG', 'B'), ('closes', '', 'O'), ('series', '', 'O'), ('b', '', 'O'), ('financing', '', 'O')]
#
# helsinki’s neosmart health raises €1.2 million to expand its patented preventative healthcare system
# Entities [('neosmart health', 'ORG')]
# Tokens [('helsinki', '', 'O'), ('’s', '', 'O'), ('neosmart', 'ORG', 'B'), ('health', 'ORG', 'I'), ('raises', '', 'O'), ('€', '', 'O'), ('1.2', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('expand', '', 'O'), ('its', '', 'O'), ('patented', '', 'O'), ('preventative', '', 'O'), ('healthcare', '', 'O'), ('system', '', 'O')]
#
# wealth manager moneyfarm raises £36 million  in funding round led by poste italiane
# Entities [('moneyfarm', 'ORG')]
# Tokens [('wealth', '', 'O'), ('manager', '', 'O'), ('moneyfarm', 'ORG', 'B'), ('raises', '', 'O'), ('£', '', 'O'), ('36', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O'), ('round', '', 'O'), ('led', '', 'O'), ('by', '', 'O'), ('poste', '', 'O'), ('italiane', '', 'O')]
#
# ferntech scores seed financing
# Entities [('ferntech', 'ORG')]
# Tokens [('ferntech', 'ORG', 'B'), ('scores', '', 'O'), ('seed', '', 'O'), ('financing', '', 'O')]
#
# intesa sanpaolo joins matipay for €7 million
# Entities []
# Tokens [('intesa', '', 'O'), ('sanpaolo', '', 'O'), ('joins', '', 'O'), ('matipay', '', 'O'), ('for', '', 'O'), ('€', '', 'O'), ('7', '', 'O'), ('million', '', 'O')]
#
# dashmote raises $2.8 million  in funding
# Entities [('dashmote', 'ORG')]
# Tokens [('dashmote', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('2.8', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# inshur raises $9 million in funding
# Entities [('inshur', 'ORG')]
# Tokens [('inshur', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('9', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('funding', '', 'O')]
#
# saas e-learning platform learnworlds gets $1.1 million in seed money to spur growth
# Entities [('learnworlds', 'ORG')]
# Tokens [('saas', '', 'O'), ('e', '', 'O'), ('-', '', 'O'), ('learning', '', 'O'), ('platform', '', 'O'), ('learnworlds', 'ORG', 'B'), ('gets', '', 'O'), ('$', '', 'O'), ('1.1', '', 'O'), ('million', '', 'O'), ('in', '', 'O'), ('seed', '', 'O'), ('money', '', 'O'), ('to', '', 'O'), ('spur', '', 'O'), ('growth', '', 'O')]
#
# gitguardian grabs $12 million series a to help companies detect loose secrets in code
# Entities [('gitguardian', 'ORG')]
# Tokens [('gitguardian', 'ORG', 'B'), ('grabs', '', 'O'), ('$', '', 'O'), ('12', '', 'O'), ('million', '', 'O'), ('series', '', 'O'), ('a', '', 'O'), ('to', '', 'O'), ('help', '', 'O'), ('companies', '', 'O'), ('detect', '', 'O'), ('loose', '', 'O'), ('secrets', '', 'O'), ('in', '', 'O'), ('code', '', 'O')]
#
# edtech startup kinteract recieves £1.25 million  financial backing
# Entities [('kinteract', 'ORG')]
# Tokens [('edtech', '', 'O'), ('startup', '', 'O'), ('kinteract', 'ORG', 'B'), ('recieves', '', 'O'), ('£', '', 'O'), ('1.25', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('financial', '', 'O'), ('backing', '', 'O')]
#
# heuritech raises €4 million to detect before the hour the fashion and luxury trends
# Entities [('heuritech', 'ORG')]
# Tokens [('heuritech', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('4', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('detect', '', 'O'), ('before', '', 'O'), ('the', '', 'O'), ('hour', '', 'O'), ('the', '', 'O'), ('fashion', '', 'O'), ('and', '', 'O'), ('luxury', '', 'O'), ('trends', '', 'O')]
#
# seven-figure sum investment into the leipzig hr-tech startup whyapply
# Entities [('whyapply', 'ORG')]
# Tokens [('seven', '', 'O'), ('-', '', 'O'), ('figure', '', 'O'), ('sum', '', 'O'), ('investment', '', 'O'), ('into', '', 'O'), ('the', '', 'O'), ('leipzig', '', 'O'), ('hr', '', 'O'), ('-', '', 'O'), ('tech', '', 'O'), ('startup', '', 'O'), ('whyapply', 'ORG', 'B')]
#
# 3d hubs raises $18 million  in series c funding
# Entities [('3d hubs', 'ORG')]
# Tokens [('3d', 'ORG', 'B'), ('hubs', 'ORG', 'I'), ('raises', '', 'O'), ('$', '', 'O'), ('18', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('c', '', 'O'), ('funding', '', 'O')]
#
# cb4 raises $16 million  in series b funding
# Entities [('cb4', 'ORG')]
# Tokens [('cb4', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('16', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('series', '', 'O'), ('b', '', 'O'), ('funding', '', 'O')]
#
# nicecactus.gg, french gaming platform raises €5.5 million  funding, gets new name
# Entities [('nicecactus.gg', 'ORG')]
# Tokens [('nicecactus.gg', 'ORG', 'B'), (',', '', 'O'), ('french', '', 'O'), ('gaming', '', 'O'), ('platform', '', 'O'), ('raises', '', 'O'), ('€', '', 'O'), ('5.5', '', 'O'), ('million', '', 'O'), (' ', '', 'O'), ('funding', '', 'O'), (',', '', 'O'), ('gets', '', 'O'), ('new', '', 'O'), ('name', '', 'O')]
#
# russian startup botkin.ai attracts $1.5 million to better diagnose cancer at early stages
# Entities [('botkin.ai', 'ORG')]
# Tokens [('russian', '', 'O'), ('startup', '', 'O'), ('botkin.ai', 'ORG', 'B'), ('attracts', '', 'O'), ('$', '', 'O'), ('1.5', '', 'O'), ('million', '', 'O'), ('to', '', 'O'), ('better', '', 'O'), ('diagnose', '', 'O'), ('cancer', '', 'O'), ('at', '', 'O'), ('early', '', 'O'), ('stages', '', 'O')]
#
# paris-based outsight raises $20 million seed round for 3d semantic camera
# Entities [('outsight', 'ORG')]
# Tokens [('paris', '', 'O'), ('-', '', 'O'), ('based', '', 'O'), ('outsight', 'ORG', 'B'), ('raises', '', 'O'), ('$', '', 'O'), ('20', '', 'O'), ('million', '', 'O'), ('seed', '', 'O'), ('round', '', 'O'), ('for', '', 'O'), ('3d', '', 'O'), ('semantic', '', 'O'), ('camera', '', 'O')]
#
# toyota, volvo lead $31 million investment in israeli co uveye
# Entities [('toyota', 'ORG')]
# Tokens [('toyota', 'ORG', 'B'), (',', '', 'O'), ('volvo', '', 'O'), ('lead', '', 'O'), ('$', '', 'O'), ('31', '', 'O'), ('million', '', 'O'), ('investment', '', 'O'), ('in', '', 'O'), ('israeli', '', 'O'), ('co', '', 'O'), ('uveye', '', 'O')]
#
# ukrainian greenbin.app raises €45,000  in polish accelerator. the company is developing a recycling app
# Entities [('greenbin.app', 'ORG')]
# Tokens [('ukrainian', '', 'O'), ('greenbin.app', 'ORG', 'B'), ('raises', '', 'O'), ('€', '', 'O'), ('45,000', '', 'O'), (' ', '', 'O'), ('in', '', 'O'), ('polish', '', 'O'), ('accelerator', '', 'O'), ('.', '', 'O'), ('the', '', 'O'), ('company', '', 'O'), ('is', '', 'O'), ('developing', '', 'O'), ('a', '', 'O'), ('recycling', '', 'O'), ('app', '', 'O')]

# %% [markdown]
# Saving to disk for later reuse.

# %%
nlp.to_disk("startup_model")

# %% [markdown]
# Loading from disk

# %%
startup_model = nlp.from_disk("startup_model")

# %% [markdown]
# Evaluating on test data

# %%
from spacy.gold import GoldParse
from spacy.scorer import Scorer

def evaluate(ner_model, examples):
    scorer = Scorer()
    for input_, annot in examples:
        doc_gold_text = ner_model.make_doc(input_)
        gold = GoldParse(doc_gold_text, entities=annot['entities'])
        pred_value = ner_model(input_)
        scorer.score(pred_value, gold)
    return scorer.scores

# %%
#print(test_data)
results = evaluate(startup_model, test_data)
results
# Out:
# {'ents_f': 91.67429094236047,
#  'ents_p': 92.09558823529412,
#  'ents_per_type': {'ORG': {'f': 91.67429094236047,
#    'p': 92.09558823529412,
#    'r': 91.2568306010929}},
#  'ents_r': 91.2568306010929,
#  'las': 0.0,
#  'las_per_type': {'': {'f': 0.0, 'p': 0.0, 'r': 0.0}},
#  'tags_acc': 0.0,
#  'textcat_score': 0.0,
#  'textcats_per_cat': {},
#  'token_acc': 100.0,
#  'uas': 0.0}

# %%
print("Recall",results["ents_r"])
print("Precision",results["ents_p"])
print("F-Measure",results["ents_f"])
# Out:
# Recall 91.2568306010929
# Precision 92.09558823529412
# F-Measure 91.67429094236047

# %% [markdown]
# Computing accuracy

# %%
labels = {}
for val in test_data:
    ents = [(ent.start_char, ent.end_char, ent.label_,ent.text)  for ent in nlp(val[0]).ents]
    for goldEntity in val[1]['entities']:
        if not goldEntity[2] in labels:
            labels[goldEntity[2]] = {'total':0,'detected':1}
        for detected in ents:
            if(detected[0] == goldEntity[0] and detected[1] == goldEntity[1] and detected[2] == goldEntity[2]):
                labels[goldEntity[2]]["detected"] += 1
        labels[goldEntity[2]]["total"] += 1

print("ACCURACY SCORE")
print("-----------------------------------------")
for key, value in labels.items():
    if value["total"]:
      print(key, value["detected"]/value["total"])
    else:
      print(key,'NO TEST DATA')
# Out:
# ACCURACY SCORE
# -----------------------------------------
# ORG 0.8980322003577818
